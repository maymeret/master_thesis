# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import cartopy.crs as ccrs
import cartopy.feature as cf
import netCDF4
import pandas as pd
import datetime
import pytz 
from tzwhere import tzwhere
import math
from suntime import Sun
import scipy as sci
from scipy import stats
from scipy.stats import norm

# %%
def get_data(len_data, NU_WU):  #len_data is the number of files i want to read in (e.g. 4 for 4h hourly data), NU_WU is a str and you can define if you want 'with urban' or 'no urban'
    ds_data = {}  
    for i in range(1, len_data + 1):
        filename = f'../det_data_all_2022/fc_DOM01_0{i:03d}_{NU_WU}_urban_grid.nc'
        try:
            ds_data[i] = xr.open_dataset(filename)
            print(f'Successfully opened {filename}')
        except FileNotFoundError:
            print(f'File not found: {filename}')
        except Exception as e:
            print(f'An error occurred while opening {filename}: {e}')
    
    return ds_data

def get_data_nights(len_data, NU_WU):  #len_data is the number of files i want to read in (e.g. 4 for 4h hourly data), NU_WU is a str and you can define if you want 'with urban' or 'no urban'
    ds_data = {}  
    for i in range(1, len_data + 1):
        filename = f'../det_data_nights_2022/fc_DOM01_0{i:03d}_{NU_WU}_urban_grid_nights.nc'
        try:
            ds_data[i] = xr.open_dataset(filename)
            print(f'Successfully opened {filename}')
        except FileNotFoundError:
            print(f'File not found: {filename}')
        except Exception as e:
            print(f'An error occurred while opening {filename}: {e}')
    
    return ds_data

def get_data_days(len_data, NU_WU):  #len_data is the number of files i want to read in (e.g. 4 for 4h hourly data), NU_WU is a str and you can define if you want 'with urban' or 'no urban'
    ds_data = {}  
    for i in range(1, len_data + 1):
        filename = f'../det_data_day_2022/fc_DOM01_0{i:03d}_{NU_WU}_urban_grid_days.nc'
        try:
            ds_data[i] = xr.open_dataset(filename)
            print(f'Successfully opened {filename}')
        except FileNotFoundError:
            print(f'File not found: {filename}')
        except Exception as e:
            print(f'An error occurred while opening {filename}: {e}')
    
    return ds_data

def get_data_ens(len_data, NU_WU, mem):
    ds_data = {}  
    for i in range(1, len_data + 1):
        filename = f'../ensemble_members_data_2022/{mem}/fc_DOM01_0{i:03d}_{mem}_{NU_WU}_urban_grid.nc'
        try:
            ds_data[i] = xr.open_dataset(filename)
            print(f'Successfully opened {filename}')
        except FileNotFoundError:
            print(f'File not found: {filename}')
        except Exception as e:
            print(f'An error occurred while opening {filename}: {e}')
    
    return ds_data

def prepare_sun(number_cities, data, file): #number of cities depends on input and % of landuse tiles, file defines in which hour you want to define since all hours are stored in one xarray dataset
    sun = {}
    for i in range(number_cities):
        sun[i] = Sun(data[file].clat[i].to_numpy()*180/math.pi, data[file].clon[i].to_numpy()*180/math.pi)
    
    return sun

def get_sunrise_sunset(number_cities, input_time, input_sun): #input_sun is the output of 'def prepare_sun'
    sunrise = {}
    sunset = {}
    for i in range(number_cities):
        sunrise[i] = input_sun[i].get_local_sunrise_time(input_time).time()
        sunrise[i] = pytz.utc.localize(sunrise[i])
    for i in range(number_cities):
        sunset[i] = input_sun[i].get_local_sunset_time(input_time).time()
        sunset[i] = pytz.utc.localize(sunset[i])
    
    return sunrise, sunset

def binary_daynight(number_cities, sunrise, sunset, hour):  
    time = datetime.time(hour)
    time = pytz.utc.localize(time)
    daynight = []
    
    for i in range(number_cities):
        if (sunset[i] < sunrise[i] and sunset[i]<= time <= sunrise[i]) or (sunset[i] > sunrise[i] and (time > sunset[i] or time < sunrise[i])):
            daynight.append('Night')
        else:
            daynight.append('Day')

    return daynight

def get_night(binary_data, data):
    data_night = {}

    for i, dataset in data.items():
        dataset = dataset.expand_dims(dim={"day_night": binary_data})
        
        data_night[i] = dataset.where(dataset['day_night'] != 'Day')
    
    return data_night, dataset

# %%
data_WU = get_data(120, 'WU')
data_NU = get_data(120, 'NU')
# Out:
# Successfully opened ../det_data_all_2022/fc_DOM01_0001_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0002_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0003_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0004_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0005_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0006_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0007_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0008_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0009_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0010_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0011_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0012_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0013_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0014_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0015_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0016_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0017_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0018_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0019_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0020_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0021_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0022_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0023_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0024_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0025_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0026_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0027_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0028_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0029_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0030_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0031_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0032_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0033_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0034_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0035_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0036_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0037_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0038_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0039_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0040_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0041_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0042_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0043_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0044_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0045_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0046_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0047_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0048_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0049_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0050_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0051_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0052_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0053_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0054_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0055_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0056_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0057_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0058_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0059_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0060_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0061_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0062_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0063_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0064_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0065_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0066_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0067_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0068_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0069_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0070_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0071_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0072_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0073_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0074_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0075_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0076_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0077_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0078_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0079_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0080_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0081_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0082_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0083_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0084_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0085_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0086_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0087_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0088_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0089_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0090_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0091_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0092_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0093_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0094_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0095_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0096_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0097_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0098_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0099_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0100_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0101_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0102_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0103_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0104_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0105_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0106_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0107_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0108_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0109_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0110_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0111_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0112_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0113_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0114_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0115_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0116_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0117_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0118_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0119_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0120_WU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0001_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0002_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0003_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0004_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0005_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0006_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0007_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0008_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0009_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0010_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0011_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0012_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0013_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0014_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0015_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0016_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0017_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0018_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0019_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0020_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0021_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0022_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0023_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0024_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0025_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0026_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0027_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0028_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0029_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0030_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0031_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0032_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0033_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0034_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0035_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0036_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0037_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0038_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0039_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0040_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0041_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0042_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0043_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0044_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0045_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0046_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0047_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0048_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0049_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0050_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0051_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0052_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0053_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0054_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0055_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0056_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0057_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0058_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0059_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0060_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0061_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0062_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0063_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0064_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0065_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0066_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0067_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0068_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0069_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0070_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0071_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0072_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0073_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0074_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0075_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0076_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0077_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0078_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0079_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0080_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0081_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0082_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0083_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0084_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0085_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0086_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0087_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0088_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0089_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0090_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0091_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0092_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0093_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0094_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0095_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0096_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0097_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0098_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0099_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0100_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0101_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0102_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0103_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0104_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0105_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0106_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0107_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0108_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0109_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0110_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0111_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0112_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0113_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0114_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0115_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0116_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0117_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0118_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0119_NU_urban_grid.nc
# Successfully opened ../det_data_all_2022/fc_DOM01_0120_NU_urban_grid.nc

# %%
data_WU_nights = get_data_nights(120, 'WU')
data_NU_nights = get_data_nights(120, 'NU')
# Out:
# Successfully opened ../det_data_nights_2022/fc_DOM01_0001_WU_urban_grid_nights.nc
# Successfully opened ../det_data_nights_2022/fc_DOM01_
WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0080_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0081_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0082_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0083_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0084_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0085_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0086_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0087_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0088_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0089_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0090_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0091_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0092_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0093_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0094_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0095_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0096_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0097_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0098_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0099_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0100_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0101_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0102_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0103_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0104_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0105_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0106_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0107_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0108_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0109_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0110_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0111_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0112_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0113_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0114_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0115_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0116_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0117_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0118_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0119_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0120_WU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0001_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0002_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0003_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0004_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0005_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0006_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0007_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0008_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0009_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0010_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0011_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0012_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0013_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0014_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0015_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0016_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0017_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0018_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0019_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0020_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0021_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0022_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0023_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0024_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0025_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0026_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0027_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0028_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0029_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0030_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0031_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0032_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0033_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0034_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0035_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0036_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0037_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0038_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0039_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0040_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0041_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0042_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0043_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0044_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0045_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0046_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0047_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0048_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0049_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0050_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0051_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0052_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0053_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0054_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0055_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0056_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0057_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0058_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0059_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0060_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0061_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0062_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0063_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0064_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0065_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0066_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0067_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0068_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0069_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0070_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0071_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0072_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0073_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0074_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0075_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0076_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0077_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0078_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0079_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0080_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0081_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0082_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0083_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0084_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0085_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0086_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0087_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0088_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0089_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0090_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0091_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0092_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0093_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0094_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0095_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0096_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0097_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0098_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0099_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0100_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0101_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0102_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0103_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0104_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0105_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0106_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0107_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0108_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0109_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0110_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0111_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0112_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0113_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0114_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0115_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0116_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0117_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0118_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0119_NU_urban_grid_days.nc
# Successfully opened ../det_data_day_2022/fc_DOM01_0120_NU_urban_grid_days.nc

# %%
# List of 40 mem values (adjust as needed)
#mem_values = [f"mem{i:03d}" for i in range(1, 5)]

# Dictionary to store results for each mem value
#data_NU_mem = {}

# Loop over mem values
#for mem_value in mem_values:
#    directory_name = f"data_NU_{mem_value}"  # Create a unique directory name
#    data_NU_mem[directory_name] = get_data_ens(120, 'NU', mem_value)

# %%
#data_NU_mem001 = get_data_ens(120, 'NU', 'mem001')
#data_NU_mem002 = get_data_ens(120, 'NU', 'mem002')
#data_NU_mem003 = get_data_ens(120, 'NU', 'mem003')
#data_NU_mem004 = get_data_ens(120, 'NU', 'mem004')
#data_NU_mem005 = get_data_ens(120, 'NU', 'mem005')
#data_NU_mem006 = get_data_ens(120, 'NU', 'mem006')
#data_NU_mem007 = get_data_ens(120, 'NU', 'mem007')
#data_NU_mem008 = get_data_ens(120, 'NU', 'mem008')
#data_NU_mem009 = get_data_ens(120, 'NU', 'mem009')
#data_NU_mem010 = get_data_ens(120, 'NU', 'mem010')
#data_NU_mem011 = get_data_ens(120, 'NU', 'mem011')
#data_NU_mem012 = get_data_ens(120, 'NU', 'mem012')
#data_NU_mem013 = get_data_ens(120, 'NU', 'mem013')
#data_NU_mem014 = get_data_ens(120, 'NU', 'mem014')
#data_NU_mem015 = get_data_ens(120, 'NU', 'mem015')
#data_NU_mem016 = get_data_ens(120, 'NU', 'mem016')
#data_NU_mem017 = get_data_ens(120, 'NU', 'mem017')
#data_NU_mem018 = get_data_ens(120, 'NU', 'mem018')
mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0068_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0069_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0070_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0071_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0072_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0073_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0074_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0075_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0076_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0077_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0078_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0079_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0080_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0081_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0082_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0083_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0084_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0085_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0086_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0087_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0088_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0089_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0090_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0091_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0092_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0093_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0094_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0095_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0096_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0097_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0098_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0099_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0100_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0101_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0102_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0103_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0104_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0105_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0106_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0107_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0108_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0109_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0110_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0111_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0112_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0113_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0114_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0115_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0116_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0117_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0118_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0119_mem020_NU_urban_grid.nc
# Successfully opened ../ensemble_members_data_2022/mem020/fc_DOM01_0120_mem020_NU_urban_grid.nc

# %%
#data_WU_mem001 = get_data_ens(120, 'WU', 'mem001')
#data_WU_mem002 = get_data_ens(120, 'WU', 'mem002')
#data_WU_mem003 = get_data_ens(120, 'WU', 'mem003')
#data_WU_mem004 = get_data_ens(120, 'WU', 'mem004')
#data_WU_mem005 = get_data_ens(120, 'WU', 'mem005')
#data_WU_mem006 = get_data_ens(120, 'WU', 'mem006')
#data_WU_mem007 = get_data_ens(120, 'WU', 'mem007')
#data_WU_mem008 = get_data_ens(120, 'WU', 'mem008')
#data_WU_mem009 = get_data_ens(120, 'WU', 'mem009')
#data_WU_mem010 = get_data_ens(120, 'WU', 'mem010')
#data_WU_mem011 = get_data_ens(120, 'WU', 'mem011')
#data_WU_mem012 = get_data_ens(120, 'WU', 'mem012')
#data_WU_mem013 = get_data_ens(120, 'WU', 'mem013')
#data_WU_mem014 = get_data_ens(120, 'WU', 'mem014')
#data_WU_mem015 = get_data_ens(120, 'WU', 'mem015')
#data_WU_mem016 = get_data_ens(120, 'WU', 'mem016')
#data_WU_mem017 = get_data_ens(120, 'WU', 'mem017')
#data_WU_mem018 = get_data_ens(120, 'WU', 'mem018')
data_WU_mem019 = get_data_ens(120, 'WU', 'mem019')
data_WU_mem020 = get_data_ens(120, 'WU', 'mem020')
#data_WU_mem021 = get_data_ens(120, 'WU', 'mem021')
#data_WU_mem022 = get_data_ens(120, 'WU', 'mem022')
#data_WU_mem023 = get_data_ens(120, 'WU', 'mem023')
#data_WU_mem024 = get_data_ens(120, 'WU', 'mem024')
#data_WU_mem025 = get_data_ens(120, 'WU', 'mem025')
#data_WU_mem026 = get_data_ens(120, 'WU', 'mem026')
#data_WU_mem027 = get_data_ens(120, 'WU', 'mem027')
#data_WU_mem028 = get_data_ens(120, 'WU', 'mem028')
#data_WU_mem029 = get_data_ens(120, 'WU', 'mem029')
#data_WU_mem030 = get_data_ens(120, 'WU', 'mem030')
#data_WU_mem031 = get_data_ens(120, 'WU', 'mem031')
#data_WU_mem032 = get_data_ens(120, 'WU', 'mem032')
#data_WU_mem033 = get_data_ens(120, 'WU', 'mem033')
#data_WU_mem034 = get_data_ens(120, 'WU', 'mem034')
#data_WU_mem035 = get_data_ens(120, 'WU', 'mem035')
#data_WU_mem036 = get_data_ens(120, 'WU', 'mem036')
#data_WU_mem037 = get_data_ens(120, 'WU', 'mem037')
#data_WU_mem038 = get_data_ens(120, 'WU', 'mem038')
#data_WU_mem039 = get_data_ens(120, 'WU', 'mem039')
#data_WU_mem040 = get_data_ens(120, 'WU', 'mem040')
# Out:
# Successfully opened ../ensemble_members_data_2022/mem019/fc_DOM01_
# %%
#create time_array for the hours because it is easier to calculate with. Added zero in the beginning because ICON output and Python have different indexing

time_array = []

for i in range(121):
    time_array.append(i % 24)

numbers_to_add = [0, 21, 22, 23]  # Numbers to add

# Use the insert method to add numbers to the beginning of the array
for num in reversed(numbers_to_add):
    time_array.insert(0, num)

# %%
#corrected version. Before the intervall between sunset and sunrise was wrongly defined for hours. Can delete the first version but just in case 

daynight_WU = {}
daynight_NU = {}

#time_array = [0,21, 22, 23, 24, 1, 2]

for i in range(1, 121):
    j = time_array[i]
    daynight_WU[i] = binary_daynight(247, sunrise_WU[i], sunset_WU[i], j)
    
for i in range(1, 121):
    j = time_array[i]
    daynight_NU[i] = binary_daynight(247, sunrise_NU[i], sunset_NU[i], j)

# %% [markdown]
# ## from here on changes have to be made!

# %%
#Here the variable "daynight" is added to the original data_WU/NU dict/datasets

data_variable = {}

for i in range(1,121):
    
    data_variable[i] = xr.DataArray(daynight_WU[i], dims=('cell',), coords={'cell': data_WU_mem020[i]['cell']})
    data_WU_mem020[i]['daynight'] = data_variable[i]

for i in range(1,121):
    
    data_variable[i] = xr.DataArray(daynight_NU[i], dims=('cell',), coords={'cell': data_NU_mem020[i]['cell']})
    data_NU_mem020[i]['daynight'] = data_variable[i]

# %%
night_cells_WU = {}
night_cells_NU = {}

for i in range(1,121):
    night_cells_WU[i] = data_WU_mem020[i].where(data_WU_mem020[i]['daynight'] == 'Night', drop=True)
    
for i in range(1,121):
    night_cells_NU[i] = data_NU_mem020[i].where(data_NU_mem020[i]['daynight'] == 'Night', drop=True)

# %%
day_cells_WU = {}
day_cells_NU = {}

for i in range(1,121):
    if 'Day' in data_WU_mem020[i]['daynight'].values:
        day_cells_WU[i] = data_WU_mem020[i].where(data_WU_mem020[i]['daynight'] == 'Day', drop=True)
    
for i in range(1,121):
    if 'Day' in data_NU_mem020[i]['daynight'].values:
        day_cells_NU[i] = data_NU_mem020[i].where(data_NU_mem020[i]['daynight'] == 'Day', drop=True)

# %%
#and safe the new Day and Night Datsets so i don't have to do all of that at the beginning of each script 

for i in range(1,121):
    path = f'../ensemble_members_nights_2022/mem020/fc_DOM01_0{i:03d}_mem020_NU_urban_grid_nights.nc'
    night_cells_NU[i].to_netcdf(path=path)

# %%
for i in range(1,121):
    path = f'../ensemble_members_nights_2022/mem020/fc_DOM01_0{i:03d}_mem020_WU_urban_grid_nights.nc'
    night_cells_WU[i].to_netcdf(path=path)

# %%
for i in range(1,121):
    path = f'../ensemble_members_days_2022/mem020/fc_DOM01_0{i:03d}_mem020_NU_urban_grid_days.nc'
    day_cells_NU[i].to_netcdf(path=path)

# %%
for i in range(1,121):
    path = f'../ensemble_members_days_2022/mem020/fc_DOM01_0{i:03d}_mem020_WU_urban_grid_days.nc'
    day_cells_WU[i].to_netcdf(path=path)

# %%
print('hallo')
# Out:
# hallo
